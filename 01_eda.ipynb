# %% [markdown]
# <a href="https://colab.research.google.com/github/Maria-kvetsko/weather_preddiction/blob/main/01_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/weather_preddiction/data/open_meteo.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1841616 entries, 0 to 1841615
# Data columns (total 18 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   location_id               int64
#  1   time                      object
#  2   temperature_2m (°C)       float64
#  3   relative_humidity_2m (%)  int64
#  4   precipitation (mm)        float64
#  5   rain (mm)                 float64
#  6   snowfall (cm)             float64
#  7   snow_depth (m)            float64
#  8   pressure_msl (hPa)        float64
#  9   cloud_cover (%)           int64
#  10  cloud_cover_low (%)       int64
#  11  cloud_cover_mid (%)       int64
#  12  cloud_cover_high (%)      int64
#  13  wind_speed_10m (km/h)     float64
#  14  wind_speed_100m (km/h)    float64
#  15  wind_direction_10m (°)    int64
#  16  wind_direction_100m (°)   int64
#  17  wind_gusts_10m (km/h)     float64
# dtypes: float64(9), int64(8), object(1)
# memory usage: 252.9+ MB

# %%
data.head()
# Out:
#    location_id              time  temperature_2m (°C)  \
# 0            0  2016-01-31T00:00                  1.6
# 1            0  2016-01-31T01:00                  1.3
# 2            0  2016-01-31T02:00                  1.1
# 3            0  2016-01-31T03:00                  0.9
# 4            0  2016-01-31T04:00                  0.6
#
#    relative_humidity_2m (%)  precipitation (mm)  rain (mm)  snowfall (cm)  \
# 0                        86                 0.0        0.0            0.0
# 1                        88                 0.0        0.0            0.0
# 2                        91                 0.0        0.0            0.0
# 3                        92                 0.0        0.0            0.0
# 4                        92                 0.0        0.0            0.0
#
#    snow_depth (m)  pressure_msl (hPa)  cloud_cover (%)  cloud_cover_low (%)  \
# 0            0.05              1013.1               98                   13
# ...

# %%
data.describe().round(1)
# Out:
#        location_id  temperature_2m (°C)  relative_humidity_2m (%)  \
# count    1841616.0            1841616.0                 1841616.0
# mean          10.0                 10.3                      73.3
# std            6.1                  9.8                      18.3
# min            0.0                -25.8                      11.0
# 25%            5.0                  2.2                      60.0
# 50%           10.0                 10.0                      77.0
# 75%           15.0                 18.1                      89.0
# max           20.0                 39.5                     100.0
#
#        precipitation (mm)  rain (mm)  snowfall (cm)  snow_depth (m)  \
# count           1841616.0  1841616.0      1841616.0       1841616.0
# mean                  0.1        0.1            0.0             0.0
# std                   0.3        0.3            0.1             0.1
# min                   0.0        0.0            0.0             0.0
# ...

# %%
data.isnull().sum()
# Out:
# location_id                 0
# time                        0
# temperature_2m (°C)         0
# relative_humidity_2m (%)    0
# precipitation (mm)          0
# rain (mm)                   0
# snowfall (cm)               0
# snow_depth (m)              0
# pressure_msl (hPa)          0
# cloud_cover (%)             0
# cloud_cover_low (%)         0
# cloud_cover_mid (%)         0
# cloud_cover_high (%)        0
# wind_speed_10m (km/h)       0
# wind_speed_100m (km/h)      0
# wind_direction_10m (°)      0
# wind_direction_100m (°)     0
# wind_gusts_10m (km/h)       0
# dtype: int64

# %%
plt.figure(figsize=(15,9))
corr_matrix = data.corr(numeric_only= True)
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Кореляційна матриця')
plt.show()

# %%
data['location_id'].value_counts()
# Out:
# location_id
# 0     87696
# 1     87696
# 2     87696
# 3     87696
# 4     87696
# 5     87696
# 6     87696
# 7     87696
# 8     87696
# 9     87696
# 10    87696
# 11    87696
# 12    87696
# 13    87696
# 14    87696
# 15    87696
# 16    87696
# 17    87696
# 18    87696
# 19    87696
# 20    87696
# Name: count, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)
